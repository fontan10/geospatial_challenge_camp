# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import geopandas as gpd
from datetime import datetime
import json
import re
import time
from shapely.geometry import shape
from pathlib import Path

GPKG_OUTPUT_FP = Path(r"data\test.gpkg")
LAYER = "test"

if GPKG_OUTPUT_FP.exists():
    gdf = gpd.read_file(GPKG_OUTPUT_FP, layer=LAYER)

gdf.head()
# Out:
# Empty DataFrame
# Columns: [zoom_level, tile_column, tile_row, tile_data]
# Index: []
